# %%
# 구현에 사용할 패키지 임포트하기
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 초기 상태의 미로 모습

# 전체 그림의 크기 및 그림을 나타내는 변수 선언
fig = plt.figure(figsize=(5, 5))
ax = plt.gca()

# 붉은 벽 그리기
plt.plot([1, 1], [0, 1], color='red', linewidth=2)
plt.plot([1, 2], [2, 2], color='red', linewidth=2)
plt.plot([2, 2], [2, 1], color='red', linewidth=2)
plt.plot([2, 3], [1, 1], color='red', linewidth=2)

# 상태를 의미하는 문자열(S0~S8) 표시
plt.text(0.5, 2.5, 'S0', size=14, ha='center')
plt.text(1.5, 2.5, 'S1', size=14, ha='center')
plt.text(2.5, 2.5, 'S2', size=14, ha='center')
plt.text(0.5, 1.5, 'S3', size=14, ha='center')
plt.text(1.5, 1.5, 'S4', size=14, ha='center')
plt.text(2.5, 1.5, 'S5', size=14, ha='center')
plt.text(0.5, 0.5, 'S6', size=14, ha='center')
plt.text(1.5, 0.5, 'S7', size=14, ha='center')
plt.text(2.5, 0.5, 'S8', size=14, ha='center')
plt.text(0.5, 2.3, 'START', ha='center')
plt.text(2.5, 0.3, 'GOAL', ha='center')

# 그림을 그릴 범위 및 눈금 제거 설정
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
plt.tick_params(axis='both', which='both', bottom=False, top=False,
                labelbottom=False, right=False, left=False, labelleft=False)

# S0에 녹색 원으로 현재 위치를 표시
line, = ax.plot([0.5], [2.5], marker="o", color='g', markersize=60)

# %%
# 정책을 결정하는 파라미터의 초깃값 theta_0를 설정

# 줄은 상태 0~7, 열은 행동방향(상,우,하,좌 순)를 나타낸다
theta_0 = np.array([[np.nan, 1, 1, np.nan],  # s0
                    [np.nan, 1, np.nan, 1],  # s1
                    [np.nan, np.nan, 1, 1],  # s2
                    [1, 1, 1, np.nan],  # s3
                    [np.nan, np.nan, 1, 1],  # s4
                    [1, np.nan, np.nan, np.nan],  # s5
                    [1, np.nan, np.nan, np.nan],  # s6
                    [1, 1, np.nan, np.nan],  # s7、※s8은 목표지점이므로 정책이 없다
                    ])

# %%
# 정책 파라미터 theta를 행동정책 pi로 변환(소프트맥스 함수 사용)하는 함수


def softmax_convert_into_pi_from_theta(theta):
    '''비율 계산에 소프트맥스 함수 사용'''

    beta = 1.0
    [m, n] = theta.shape  # theta의 행렬 크기를 구함
    pi = np.zeros((m, n))

    exp_theta = np.exp(beta * theta)  # theta를 exp(theta)로 변환

    for i in range(0, m):
        # pi[i, :] = theta[i, :] / np.nansum(theta[i, :])
        # 단순 비율을 계산하는 코드

        pi[i, :] = exp_theta[i, :] / np.nansum(exp_theta[i, :])
        # softmax로 계산하는 코드

    pi = np.nan_to_num(pi)  # nan을 0으로 변환

    return pi

# %%
# 초기 정책 pi_0을 계산
pi_0 = softmax_convert_into_pi_from_theta(theta_0)
print(pi_0)
# Out:
# [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]

# %%
# 행동 a를 취한 후의 상태 s를 구하는 함수

def get_action_and_next_s(pi, s):
    direction = ["up", "right", "down", "left"]
    # pi[s,:]의 확률을 따라, direction값이 선택된다
    next_direction = np.random.choice(direction, p=pi[s, :])

    if next_direction == "up":
        action = 0
        s_next = s - 3  # 위로 이동하면 상태값이 3 줄어든다
    elif next_direction == "right":
        action = 1
        s_next = s + 1  # 오른쪽으로 이동하면 상태값이 1 늘어난다
    elif next_direction == "down":
        action = 2
        s_next = s + 3  # 아래로 이동하면 상태값이 3 늘어난다
    elif next_direction == "left":
        action = 3
        s_next = s - 1  # 왼쪽으로 이동하면 상태값이 1 줄어든다

    return [action, s_next]

# %%
# 미로를 빠져나오는 함수, 상태와 행동의 히스토리를 출력한다


def goal_maze_ret_s_a(pi):
    s = 0  # 시작 지점
    s_a_history = [[0, np.nan]]  # 에이전트의 행동 및 상태의 히스토리를 기록하는 리스트

    while (1):  # 목표 지점에 이를 때까지 반복
        [action, next_s] = get_action_and_next_s(pi, s)
        s_a_history[-1][1] = action
        # 현재 상태(마지막이므로 인덱스가 -1)를 히스토리에 추가

        s_a_history.append([next_s, np.nan])
        # 다음 상태를 히스토리에 추가, 행동은 아직 알 수 없으므로 nan으로 둔다.

        if next_s == 8:  # 목표 지점에 이르면 종료
            break
        else:
            s = next_s

    return s_a_history

# %%
# 초기 정책으로 미로를 빠져나오기
s_a_history = goal_maze_ret_s_a(pi_0)
print(s_a_history)
print("목표 지점에 이르기까지 걸린 단계 수는 " + str(len(s_a_history) - 1) + "단계입니다")
# Out:
# [[0, 2], [3, 2], [6, 0], [3, 2], [6, 0], [3, 2], [6, 0], [3, 2], [6, 0], [3, 0], [0, 1], [1, 3], [0, 1], [1, 1], [2, 3], [1, 1], [2, 3], [1, 3], [0, 1], [1, 1], [2, 3], [1, 1], [2, 2], [5, 0], [2, 3], [1, 3], [0, 2], [3, 2], [6, 0], [3, 2], [6, 0], [3, 0], [0, 2], [3, 2], [6, 0], [3, 0], [0, 2], [3, 0], [0, 1], [1, 3], [0, 1], [1, 3], [0, 2], [3, 1], [4, 2], [7, 0], [4, 3], [3, 1], [4, 2], [7, 0], [4, 3], [3, 0], [0, 2], [3, 1], [4, 3], [3, 0], [0, 2], [3, 2], [6, 0], [3, 2], [6, 0], [3, 1], [4, 3], [3, 2], [6, 0], [3, 0], [0, 2], [3, 0], [0, 2], [3, 0], [0, 2], [3, 1], [4, 2], [7, 1], [8, nan]]
# 목표 지점에 이르기까지 걸린 단계 수는 74단계입니다

# %%
# theta를 수정하는 함수

def update_theta(theta, pi, s_a_history):
    eta = 0.1 # 학습률
    T = len(s_a_history) - 1  # 목표 지점에 이르기까지 걸린 단계 수

    [m, n] = theta.shape  # theta의 행렬 크기를 구함
    delta_theta = theta.copy()  # Δtheta를 구할 준비, 포인터 참조이므로 delta_theta = theta로는 안됨

    # delta_theta를 요소 단위로 계산
    for i in range(0, m):
        for j in range(0, n):
            if not(np.isnan(theta[i, j])):  # theta가 nan이 아닌 경우

                SA_i = [SA for SA in s_a_history if SA[0] == i]
                # 히스토리에서 상태 i인 것만 모아오는 리스트 컴프리헨션

                SA_ij = [SA for SA in s_a_history if SA == [i, j]]
                # 상태 i에서 행동 j를 취한 경우만 모음

                N_i = len(SA_i)  # 상태 i에서 모든 행동을 취한 횟수
                N_ij = len(SA_ij)  # 상태 i에서 행동 j를 취한 횟수 
                
                # 초판에서 부호 오류가 있었음(수정일 : 1807030
                #delta_theta[i, j] = (N_ij + pi[i, j] * N_i) / T
                delta_theta[i, j] = (N_ij - pi[i, j] * N_i) / T

    new_theta = theta + eta * delta_theta

    return new_theta

# %%
# 정책 수정
new_theta = update_theta(theta_0, pi_0, s_a_history)
pi = softmax_convert_into_pi_from_theta(new_theta)
print(pi)
# Out:
# [[0.         0.49831082 0.50168918 0.        ]
#  [0.         0.49966216 0.         0.50033784]
#  [0.         0.         0.49898649 0.50101351]
#  [0.33378267 0.3319833  0.33423403 0.        ]
#  [0.         0.         0.49966216 0.50033784]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.50033784 0.49966216 0.         0.        ]]

# %%
# 정책 경사 알고리즘으로 미로 빠져나오기

stop_epsilon = 1e-5  # 정책의 변화가 10^-4 보다 작아지면 학습을 종료


theta = theta_0
pi = pi_0

is_continue = True
count = 1
while is_continue:  # is_continue가 False가 될 때까지 반복
    s_a_history = goal_maze_ret_s_a(pi)  # 정책 π를 따라 미로를 탐색한 히스토리를 구함
    new_theta = update_theta(theta, pi, s_a_history)  # 파라미터 Θ를 수정
    new_pi = softmax_convert_into_pi_from_theta(new_theta)  # 정책 π를 수정

    print(np.sum(np.abs(new_pi - pi)))  # 정책의 변화를 출력
    print(f"EPOCH : {count} | 목표 지점에 이르기까지 걸린 단계 수는 " + str(len(s_a_history) - 1) + "단계입니다")

    if np.sum(np.abs(new_pi - pi)) < stop_epsilon:
        is_continue = False
    else:
        theta = new_theta
        pi = new_pi
        count += 1
# Out:
# 0.03167720807255181
# EPOCH : 1 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.013693865957498885
# EPOCH : 2 | 목표 지점에 이르기까지 걸린 단계 수는 42단계입니다
# 0.024535912417601558
# EPOCH : 3 | 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.030280780743237867
# EPOCH : 4 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.01194991367480891
# EPOCH : 5 | 목표 지점에 이르기까지 걸린 단계 수는 52단계입니다
# 0.011784159249255133
# EPOCH : 6 | 목표 지점에 이르기까지 걸린 단계 수는 44단계입니다
# 0.02919217815116204
# EPOCH : 7 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.014207357032742784
# EPOCH : 8 | 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.010282379634338978
# EPOCH : 9 | 목표 지점에 이르기까지 걸린 단계 수는 24단계입니다
# 0.028383302066377403
# EPOCH : 10 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.018598301788090854
# EPOCH : 11 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.013295140698380337
# EPOCH : 12 | 목표 지점에 이르기까지 걸린 단계 수는 22단계입니다
# 0.01562913396365756
# EPOCH : 13 | 목표 지점에 이르기까지 걸린 단계 수는 30단계입니다
# 0.012365036151540554
# EPOCH : 14 | 목표 지점에 이르기까지 걸린 단계 수는 30단계입니다
# 0.008839682148279238
# EPOCH : 15 | 목표 지점에 이르기까지 걸린 단계 수는 86단계입니다
# 0.03152401841086644
# EPOCH : 16 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.032340102820129946
# EPOCH : 17 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.0056943775362372495
# EPOCH : 18 | 목표 지점에 이르기까지 걸린 단계 수는 96단계입니다
# 0.01222038702349193
# EPOCH : 19 | 목표 지점에 이르기까지 걸린 단계 수는 60단계입니다
# 0.018972018738139418
# EPOCH : 20 | 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.008566527272438507
# EPOCH : 21 | 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.008034363470531991
# EPOCH : 22 | 목표 지점에 이르기까지 걸린 단계 수는 30단계입니다
# 0.035509688860290156
# EPOCH : 23 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.020258220481619182
# EPOCH : 24 | 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.013189225471751276
# EPOCH : 25 | 목표 지점에 이르기까지 걸린 단계 수는 40단계입니다
# 0.04687264284458381
# EPOCH : 26 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.013964302180923704
# EPOCH : 27 | 목표 지점에 이르기까지 걸린 단계 수는 26단계입니다
# 0.008211398293260841
# EPOCH : 28 | 목표 지점에 이르기까지 걸린 단계 수는 174단계입니다
# 0.011282375708151549
# EPOCH : 29 | 목표 지점에 이르기까지 걸린 단계 수는 78단계입니다
# 0.017575186088077344
# EPOCH : 30 | 목표 지점에 이르기까지 걸린 단계 수는 34단계입니다
# 0.015540824627159
# EPOCH : 31 | 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.028233762416514763
# EPOCH : 32 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.00838820497465359
# EPOCH : 33 | 목표 지점에 이르기까지 걸린 단계 수는 90단계입니다
# 0.019261710309989077
# EPOCH : 34 | 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.024411037384372947
# EPOCH : 35 | 목표 지점에 이르기까지 걸린 단계 수는 26단계입니다
# 0.01962173408343898
# EPOCH : 36 | 목표 지점에 이르기까지 걸린 단계 수는 22단계입니다
# 0.046007815153304044
# EPOCH : 37 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.020334884859099123
# EPOCH : 38 | 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.01114019337788058
# EPOCH : 39 | 목표 지점에 이르기까지 걸린 단계 수는 48단계입니다
# 0.004741389639967564
# EPOCH : 40 | 목표 지점에 이르기까지 걸린 단계 수는 52단계입니다
# 0.023409871942733473
# EPOCH : 41 | 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.024551455651068144
# EPOCH : 42 | 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.04528704737310235
# EPOCH : 43 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.011926562174372768
# EPOCH : 44 | 목표 지점에 이르기까지 걸린 단계 수는 132단계입니다
# 0.011180235106871161
# EPOCH : 45 | 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.0317089965431685
# EPOCH : 46 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.01303587924231453
# EPOCH : 47 | 목표 지점에 이르기까지 걸린 단계 수는 22단계입니다
# 0.03594648560172631
# EPOCH : 48 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.009592861325129709
# EPOCH : 49 | 목표 지점에 이르기까지 걸린 단계 수는 38단계입니다
# 0.010540882859036538
# EPOCH : 50 | 목표 지점에 이르기까지 걸린 단계 수는 112단계입니다
# 0.014102015066450369
# EPOCH : 51 | 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.015168535715094134
# EPOCH : 52 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.0076683622411278796
# EPOCH : 53 | 목표 지점에 이르기까지 걸린 단계 수는 98단계입니다
# 0.03125527265439182
# EPOCH : 54 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.014568113483513667
# EPOCH : 55 | 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.02160530604479516
# EPOCH : 56 | 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.016020905648345907
# EPOCH : 57 | 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.023292293168740374
# EPOCH : 58 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.03253983431495988
# EPOCH : 59 | 목표 지점에 이르기까지 걸린 단계 수는 22단계입니다
# 0.023354419233609036
# EPOCH : 60 | 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.019858331840697963
# EPOCH : 61 | 목표 지점에 이르기까지 걸린 단계 수는 30단계입니다
# 0.017009893770355777
# EPOCH : 62 | 목표 지점에 이르기까지 걸린 단계 수는 22단계입니다
# 0.01056477807306433
# EPOCH : 63 | 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.013787508265795057
# EPOCH : 64 | 목표 지점에 이르기까지 걸린 단계 수는 28단계입니다
# 0.024458014707075537
# EPOCH : 65 | 목표 지점에 이르기까지 걸린 단계 수는 24단계입니다
# 0.029834138347095807
# EPOCH : 66 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.013449403953441408
# EPOCH : 67 | 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.01048042422736084
# EPOCH : 68 | 목표 지점에 이르기까지 걸린 단계 수는 28단계입니다
# 0.01922217746303606
# EPOCH : 69 | 목표 지점에 이르기까지 걸린 단계 수는 34단계입니다
# 0.01779722084925006
# EPOCH : 70 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.014306099803788386
# EPOCH : 71 | 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.0338065962917764
# EPOCH : 72 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.016605783876710745
# EPOCH : 73 | 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.014348999050537603
# EPOCH : 74 | 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.01595870252185927
# EPOCH : 75 | 목표 지점에 이르기까지 걸린 단계 수는 36단계입니다
# 0.021345342729693073
# EPOCH : 76 | 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.012610525114789828
# EPOCH : 77 | 목표 지점에 이르기까지 걸린 단계 수는 34단계입니다
# 0.01926000880189449
# EPOCH : 78 | 목표 지점에 이르기까지 걸린 단계 수는 26단계입니다
# 0.020522054694745273
# EPOCH : 79 | 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.012548542370008298
# EPOCH : 80 | 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.016659683051318874
# EPOCH : 81 | 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.031076846412727344
# EPOCH : 82 | 목표 지점에 이르기까지 걸린 단계 수는 40단계입니다
# 0.04232695023105437
# EPOCH : 83 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.017604128723306245
# EPOCH : 84 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.017393728660156094
# EPOCH : 85 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.014187402657779402
# EPOCH : 86 | 목표 지점에 이르기까지 걸린 단계 수는 44단계입니다
# 0.04153763637032659
# EPOCH : 87 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.015282058711378
# EPOCH : 88 | 목표 지점에 이르기까지 걸린 단계 수는 26단계입니다
# 0.03205596296575808
# EPOCH : 89 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.015738573766439945
# EPOCH : 90 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.02946363720213796
# EPOCH : 91 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.021848034693222773
# EPOCH : 92 | 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.025905001674073336
# EPOCH : 93 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.032061246229736995
# EPOCH : 94 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.012833342510119472
# EPOCH : 95 | 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.039432490830634825
# EPOCH : 96 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.03655579508267781
# EPOCH : 97 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.029884264976349384
# EPOCH : 98 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.024719024951120216
# EPOCH : 99 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.022454535233940143
# EPOCH : 100 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.012736688906052118
# EPOCH : 101 | 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.01592147895202417
# EPOCH : 102 | 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.028156511002634665
# EPOCH : 103 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.008948482159769622
# EPOCH : 104 | 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.011017037014777575
# EPOCH : 105 | 목표 지점에 이르기까지 걸린 단계 수는 28단계입니다
# 0.015194230575007128
# EPOCH : 106 | 목표 지점에 이르기까지 걸린 단계 수는 54단계입니다
# 0.008827351900926761
# EPOCH : 107 | 목표 지점에 이르기까지 걸린 단계 수는 40단계입니다
# 0.03789256198479446
# EPOCH : 108 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.03737558444938749
# EPOCH : 109 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.036861813014378575
# EPOCH : 110 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.026757143596553845
# EPOCH : 111 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.03607306454241904
# EPOCH : 112 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.021352686962036016
# EPOCH : 113 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.009662656763380906
# EPOCH : 114 | 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.01975488490531002
# EPOCH : 115 | 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.013307631675237852
# EPOCH : 116 | 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.010639276069284498
# EPOCH : 117 | 목표 지점에 이르기까지 걸린 단계 수는 34단계입니다
# 0.0207112534244982
# EPOCH : 118 | 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.01160577828747672
# EPOCH : 119 | 목표 지점에 이르기까지 걸린 단계 수는 28단계입니다
# 0.026022993690887453
# EPOCH : 120 | 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.01962859895429836
# EPOCH : 121 | 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.01145609665670505
# EPOCH : 122 | 목표 지점에 이르기까지 걸린 단계 수는 62단계입니다
# 0.009780112911490557
# EPOCH : 123 | 목표 지점에 이르기까지 걸린 단계 수는 66단계입니다
# 0.010852115143594188
# EPOCH : 124 | 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.028658848558862804
# EPOCH : 125 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.020671223013140005
# EPOCH : 126 | 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.011658500503777702
# EPOCH : 127 | 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.015313356440019077
# EPOCH : 128 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.015222017904208462
# EPOCH : 129 | 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.03539673255836351
# EPOCH : 130 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.034895104416349354
# EPOCH : 131 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.016360489808118495
# EPOCH : 132 | 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.012099939456985398
# EPOCH : 133 | 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.015695992823015037
# EPOCH : 134 | 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.015612882719191423
# EPOCH : 135 | 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.014174689455814682
# EPOCH : 136 | 목표 지점에 이르기까지 걸린 단계 수는 32단계입니다
# 0.01188886765841346
# EPOCH : 137 | 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.02128980348199222
# EPOCH : 138 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.017239455683569993
# EPOCH : 139 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.03165013459876015
# EPOCH : 140 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.008923956652722664
# EPOCH : 141 | 목표 지점에 이르기까지 걸린 단계 수는 32단계입니다
# 0.0246947967450869
# EPOCH : 142 | 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.03414968941698299
# EPOCH : 143 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.014496659186789718
# EPOCH : 144 | 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.020962566281955558
# EPOCH : 145 | 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.018109536215882654
# EPOCH : 146 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.013963385645675147
# EPOCH : 147 | 목표 지점에 이르기까지 걸린 단계 수는 30단계입니다
# 0.021120507725702314
# EPOCH : 148 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.007101040897306454
# EPOCH : 149 | 목표 지점에 이르기까지 걸린 단계 수는 24단계입니다
# 0.009494687828384557
# EPOCH : 150 | 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.027908627708528283
# EPOCH : 151 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.014479845312610318
# EPOCH : 152 | 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.01729716387425012
# EPOCH : 153 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.011141894499856558
# EPOCH : 154 | 목표 지점에 이르기까지 걸린 단계 수는 40단계입니다
# 0.01885484740135368
# EPOCH : 155 | 목표 지점에 이르기까지 걸린 단계 수는 22단계입니다
# 0.015133307610358221
# EPOCH : 156 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.017232233555145304
# EPOCH : 157 | 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.01592975015811443
# EPOCH : 158 | 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.03330517186926241
# EPOCH : 159 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.03282476457338884
# EPOCH : 160 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.03013179841284397
# EPOCH : 161 | 목표 지점에 이르기까지 걸린 단계 수는 24단계입니다
# 0.025314560554158816
# EPOCH : 162 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.013165055520949709
# EPOCH : 163 | 목표 지점에 이르기까지 걸린 단계 수는 24단계입니다
# 0.011976843847508772
# EPOCH : 164 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.01984247018457258
# EPOCH : 165 | 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.00909638277598962
# EPOCH : 166 | 목표 지점에 이르기까지 걸린 단계 수는 54단계입니다
# 0.012324518247785493
# EPOCH : 167 | 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.023897044437809378
# EPOCH : 168 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.03217721943248808
# EPOCH : 169 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.015868017485457186
# EPOCH : 170 | 목표 지점에 이르기까지 걸린 단계 수는 32단계입니다
# 0.011637405568370479
# EPOCH : 171 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.03169177365065695
# EPOCH : 172 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.010697078357185336
# EPOCH : 173 | 목표 지점에 이르기까지 걸린 단계 수는 48단계입니다
# 0.013544125959920439
# EPOCH : 174 | 목표 지점에 이르기까지 걸린 단계 수는 24단계입니다
# 0.015843828830548412
# EPOCH : 175 | 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.031426318290865674
# EPOCH : 176 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.03096559751673192
# EPOCH : 177 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.030510522812683183
# EPOCH : 178 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.014556548500465394
# EPOCH : 179 | 목표 지점에 이르기까지 걸린 단계 수는 26단계입니다
# 0.01917390715125153
# EPOCH : 180 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.014803323906131372
# EPOCH : 181 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.014880684139996658
# EPOCH : 182 | 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.030060295252351626
# EPOCH : 183 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.02258754684135242
# EPOCH : 184 | 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.02963169638251717
# EPOCH : 185 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.020360319617019063
# EPOCH : 186 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.014612727499097117
# EPOCH : 187 | 목표 지점에 이르기까지 걸린 단계 수는 40단계입니다
# 0.01907006104154335
# EPOCH : 188 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.029082192119785633
# EPOCH : 189 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0286518891440391
# EPOCH : 190 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.009204460491761907
# EPOCH : 191 | 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.01861478304808653
# EPOCH : 192 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.01744177282422249
# EPOCH : 193 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.01728959506744343
# EPOCH : 194 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.015227149854644656
# EPOCH : 195 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.027629600368647644
# EPOCH : 196 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0272229617118577
# EPOCH : 197 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0147681312000707
# EPOCH : 198 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.026756065591613254
# EPOCH : 199 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.014471352952331623
# EPOCH : 200 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.026300269001174992
# EPOCH : 201 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.013237833917444514
# EPOCH : 202 | 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.022293902937646604
# EPOCH : 203 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.015083315702490802
# EPOCH : 204 | 목표 지점에 이르기까지 걸린 단계 수는 42단계입니다
# 0.022039924232365865
# EPOCH : 205 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.019552569214863202
# EPOCH : 206 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.021639057269346867
# EPOCH : 207 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.021086393233988726
# EPOCH : 208 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.02540433707106879
# EPOCH : 209 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.026031118212380883
# EPOCH : 210 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.013507302458457104
# EPOCH : 211 | 목표 지점에 이르기까지 걸린 단계 수는 22단계입니다
# 0.025005297637992918
# EPOCH : 212 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.017257034528375625
# EPOCH : 213 | 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.01675340426580238
# EPOCH : 214 | 목표 지점에 이르기까지 걸린 단계 수는 24단계입니다
# 0.01789491981415761
# EPOCH : 215 | 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.02497826407312559
# EPOCH : 216 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.024001884431367054
# EPOCH : 217 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.015530636830283884
# EPOCH : 218 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.017618433469119038
# EPOCH : 219 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.02060846622354237
# EPOCH : 220 | 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.02379109630888082
# EPOCH : 221 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.02022757258550173
# EPOCH : 222 | 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.02428786921461648
# EPOCH : 223 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.01370817080473613
# EPOCH : 224 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.020342289853926554
# EPOCH : 225 | 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.020705291076757976
# EPOCH : 226 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.01193392034199342
# EPOCH : 227 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.015387984435105972
# EPOCH : 228 | 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.016181816885108946
# EPOCH : 229 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.028398915146768317
# EPOCH : 230 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.024030261263343372
# EPOCH : 231 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.023678923848527322
# EPOCH : 232 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.023442210508493516
# EPOCH : 233 | 목표 지점에 이르기까지 걸린 단계 수는 22단계입니다
# 0.015881673293234033
# EPOCH : 234 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.01778742002536271
# EPOCH : 235 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.018598508284240617
# EPOCH : 236 | 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.015569835086053613
# EPOCH : 237 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.01768038788159748
# EPOCH : 238 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.023159799563388817
# EPOCH : 239 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.022822194454504285
# EPOCH : 240 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.013061796607858
# EPOCH : 241 | 목표 지점에 이르기까지 걸린 단계 수는 26단계입니다
# 0.01524730052426096
# EPOCH : 242 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.014681396218132886
# EPOCH : 243 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.012936991114185947
# EPOCH : 244 | 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.017439938616149064
# EPOCH : 245 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.03121362076040038
# EPOCH : 246 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.025712782750753338
# EPOCH : 247 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.019711684682926695
# EPOCH : 248 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.014560128549563844
# EPOCH : 249 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.02229249970459568
# EPOCH : 250 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.02523696075812948
# EPOCH : 251 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.021889010686389765
# EPOCH : 252 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.016557958970117276
# EPOCH : 253 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.0216324820055028
# EPOCH : 254 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.016292522090690265
# EPOCH : 255 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.022252748035231
# EPOCH : 256 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.014923928697914562
# EPOCH : 257 | 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.01084845040145449
# EPOCH : 258 | 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.013078781430631098
# EPOCH : 259 | 목표 지점에 이르기까지 걸린 단계 수는 26단계입니다
# 0.021288564027939355
# EPOCH : 260 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.019187501266043905
# EPOCH : 261 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.01612716402844419
# EPOCH : 262 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.01613881756162089
# EPOCH : 263 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.013869075609323794
# EPOCH : 264 | 목표 지점에 이르기까지 걸린 단계 수는 18단계입니다
# 0.02081643477689346
# EPOCH : 265 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.01895086395670295
# EPOCH : 266 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.02140309379953048
# EPOCH : 267 | 목표 지점에 이르기까지 걸린 단계 수는 34단계입니다
# 0.024188372000693653
# EPOCH : 268 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.01202839781037715
# EPOCH : 269 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.020375801932879967
# EPOCH : 270 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.020085693352610123
# EPOCH : 271 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.021434849415126356
# EPOCH : 272 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.010583986919572963
# EPOCH : 273 | 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.021271892169878265
# EPOCH : 274 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.014724331753074527
# EPOCH : 275 | 목표 지점에 이르기까지 걸린 단계 수는 30단계입니다
# 0.019881831008546264
# EPOCH : 276 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.019597924090703628
# EPOCH : 277 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.011825645754252129
# EPOCH : 278 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.01931459257878576
# EPOCH : 279 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.015599317509187194
# EPOCH : 280 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.02340246972073809
# EPOCH : 281 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.017942116632334443
# EPOCH : 282 | 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.01904770417579485
# EPOCH : 283 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.022811750214219134
# EPOCH : 284 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.012867436666142873
# EPOCH : 285 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.018726992019483135
# EPOCH : 286 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.01846313984297518
# EPOCH : 287 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.018203611040916945
# EPOCH : 288 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.022218713902411286
# EPOCH : 289 | 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.0134382563796131
# EPOCH : 290 | 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.022401805433860306
# EPOCH : 291 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.015944000583706153
# EPOCH : 292 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.018577556957056957
# EPOCH : 293 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.022276306986623695
# EPOCH : 294 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.014013517891906718
# EPOCH : 295 | 목표 지점에 이르기까지 걸린 단계 수는 26단계입니다
# 0.011204023949850428
# EPOCH : 296 | 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.018608589416037852
# EPOCH : 297 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.018344151674436704
# EPOCH : 298 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.017072453050090308
# EPOCH : 299 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.015029464969502748
# EPOCH : 300 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.014179106535696373
# EPOCH : 301 | 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.017012182245013552
# EPOCH : 302 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.011338881822156088
# EPOCH : 303 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.018123297133022603
# EPOCH : 304 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.019784345639002776
# EPOCH : 305 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.014639354947763111
# EPOCH : 306 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.01780317156218658
# EPOCH : 307 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.016726593735673256
# EPOCH : 308 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.0126884439702942
# EPOCH : 309 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.017431257604902523
# EPOCH : 310 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.019184053867272094
# EPOCH : 311 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.01710574357567729
# EPOCH : 312 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.01686426993216178
# EPOCH : 313 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.016626946270982518
# EPOCH : 314 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.013044495844810794
# EPOCH : 315 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.021766852450365026
# EPOCH : 316 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.01638971066799949
# EPOCH : 317 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.016352667128167797
# EPOCH : 318 | 목표 지점에 이르기까지 걸린 단계 수는 34단계입니다
# 0.016181104901036414
# EPOCH : 319 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.015955683692462225
# EPOCH : 320 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.021277999910991302
# EPOCH : 321 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.01569385983458163
# EPOCH : 322 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.017115928563554567
# EPOCH : 323 | 목표 지점에 이르기까지 걸린 단계 수는 26단계입니다
# 0.012725059568664987
# EPOCH : 324 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.01565209326347622
# EPOCH : 325 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.021657917445934816
# EPOCH : 326 | 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.015596962744828358
# EPOCH : 327 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.014047978134011818
# EPOCH : 328 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.01541999919572229
# EPOCH : 329 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.015239674425828992
# EPOCH : 330 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.016640364762722987
# EPOCH : 331 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.0172215364857585
# EPOCH : 332 | 목표 지점에 이르기까지 걸린 단계 수는 22단계입니다
# 0.020875142172033984
# EPOCH : 333 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.015406316573264606
# EPOCH : 334 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.015195378049171482
# EPOCH : 335 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.014988042588928191
# EPOCH : 336 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.014260193762406281
# EPOCH : 337 | 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.016932333752925716
# EPOCH : 338 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.014941064398123649
# EPOCH : 339 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.01473848921227977
# EPOCH : 340 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.014539357561812655
# EPOCH : 341 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.014343608689489945
# EPOCH : 342 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.012457453559399645
# EPOCH : 343 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.015171363525527087
# EPOCH : 344 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.015051740493283533
# EPOCH : 345 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.
| 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.011083004558790494
# EPOCH : 429 | 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.010716013998246135
# EPOCH : 430 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.012591792457820203
# EPOCH : 431 | 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 0.012659843878027988
# EPOCH : 432 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.010794000004961377
# EPOCH : 433 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.012661726287300057
# EPOCH : 434 | 목표 지점에 이르기까지 걸린 단계 수는 16단계입니다
# 0.010657444723440768
# EPOCH : 435 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.009847759673705464
# EPOCH : 436 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.014328663507333542
# EPOCH : 437 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.010587039821970484
# EPOCH : 438 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.014804957892769699
# EPOCH : 439 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.010517920888905435
# EPOCH : 440 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.010389488939259894
# EPOCH : 441 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.014002643726372874
# EPOCH : 442 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.010246723669127558
# EPOCH : 443 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.012900196227264613
# EPOCH : 444 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.010125848182364464
# EPOCH : 445 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.01000344795021521
# EPOCH : 446 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.009883014645892696
# EPOCH : 447 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.013773210822521587
# EPOCH : 448 | 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.009871323632582266
# EPOCH : 449 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.011841756501560871
# EPOCH : 450 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.009807507624568071
# EPOCH : 451 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.009110615054739174
# EPOCH : 452 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.013968267943549287
# EPOCH : 453 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.009178912019279076
# EPOCH : 454 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.009803478946542904
# EPOCH : 455 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.009686263677860296
# EPOCH : 456 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.018678242543951715
# EPOCH : 457 | 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.013528900939945673
# EPOCH : 458 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.009666181985973202
# EPOCH : 459 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.009551224010290113
# EPOCH : 460 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.013274200343856582
# EPOCH : 461 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.009428332867371408
# EPOCH : 462 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.009317036530146428
# EPOCH : 463 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.01634555787211088
# EPOCH : 464 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.012216332058445842
# EPOCH : 465 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.009213920823380004
# EPOCH : 466 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.009105957163560996
# EPOCH : 467 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.015113452891882734
# EPOCH : 468 | 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.013137364430673384
# EPOCH : 469 | 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.009135807955824957
# EPOCH : 470 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.009029195648635177
# EPOCH : 471 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.008859423621858181
# EPOCH : 472 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.008938953641206324
# EPOCH : 473 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.01498544825808161
# EPOCH : 474 | 목표 지점에 이르기까지 걸린 단계 수는 30단계입니다
# 0.008848918182231477
# EPOCH : 475 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.008746883535561634
# EPOCH : 476 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.008739296112806341
# EPOCH : 477 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.008663689918122025
# EPOCH : 478 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.008564581495803969
# EPOCH : 479 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.008467000319020757
# EPOCH : 480 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.00837091858236183
# EPOCH : 481 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.008892116491396304
# EPOCH : 482 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.008277375855890057
# EPOCH : 483 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.008659872725108875
# EPOCH : 484 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.008241447713649139
# EPOCH : 485 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.008148870916162482
# EPOCH : 486 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.01126366221009964
# EPOCH : 487 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.009367197330542365
# EPOCH : 488 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.008152731608664435
# EPOCH : 489 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.008061340884008436
# EPOCH : 490 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.01164990638554013
# EPOCH : 491 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.011640498616203185
# EPOCH : 492 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.008546969293960469
# EPOCH : 493 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.023800821347255918
# EPOCH : 494 | 목표 지점에 이르기까지 걸린 단계 수는 20단계입니다
# 0.00810107740894793
# EPOCH : 495 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.008010290895726246
# EPOCH : 496 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.014486629956128386
# EPOCH : 497 | 목표 지점에 이르기까지 걸린 단계 수는 36단계입니다
# 0.011828067672970094
# EPOCH : 498 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.011838060518619117
# EPOCH : 499 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.008047925074397999
# EPOCH : 500 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.011159250895494827
# EPOCH : 501 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.007975410478839984
# EPOCH : 502 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.010892438406985755
# EPOCH : 503 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.00798100311131518
# EPOCH : 504 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.00789210534253465
# EPOCH : 505 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.00780454969644849
# EPOCH : 506 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.014645373023429012
# EPOCH : 507 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.00779090886010618
# EPOCH : 508 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.00770468872621316
# EPOCH : 509 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.007619767254302134
# EPOCH : 510 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.
| 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.004984996432370395
# EPOCH : 676 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.008698412101377659
# EPOCH : 677 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.004967419815681939
# EPOCH : 678 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.00492094508648884
# EPOCH : 679 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.008749719524868665
# EPOCH : 680 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.004892033225444653
# EPOCH : 681 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.004846536677420077
# EPOCH : 682 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.004801639931859086
# EPOCH : 683 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.006952476956362974
# EPOCH : 684 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.008671788794321747
# EPOCH : 685 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.004788503986327894
# EPOCH : 686 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.004744377925263513
# EPOCH : 687 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.004700828621768738
# EPOCH : 688 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.006867048200527609
# EPOCH : 689 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.011735301655183716
# EPOCH : 690 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.008544850179336427
# EPOCH : 691 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.004775940792928868
# EPOCH : 692 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.004731797492781006
# EPOCH : 693 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.008546975436987417
# EPOCH : 694 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.004705981457604258
# EPOCH : 695 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0046627389256770485
# EPOCH : 696 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.004620061646134099
# EPOCH : 697 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.012802181519794814
# EPOCH : 698 | 목표 지점에 이르기까지 걸린 단계 수는 22단계입니다
# 0.008452177410873021
# EPOCH : 699 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.011586752045822962
# EPOCH : 700 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.0047022531259929695
# EPOCH : 701 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.02246698145712768
# EPOCH : 702 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.006869633141125681
# EPOCH : 703 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.00468404319060256
# EPOCH : 704 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.004641052101262713
# EPOCH : 705 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.004598622763565041
# EPOCH : 706 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.004556745863441028
# EPOCH : 707 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.004515412269923094
# EPOCH : 708 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.011449286063184641
# EPOCH : 709 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.004527434994731891
# EPOCH : 710 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0044864261910172315
# EPOCH : 711 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.004445947312379683
# EPOCH : 712 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0082847182727947
# EPOCH : 713 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.004435238274244455
# EPOCH : 714 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.009112022471180675
# EPOCH : 715 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 0.010667848644945188
# EPOCH : 716 | 목표 지점에 이르기까지 걸린 단계 수는 12단계입니다
# 0.008434615324075023
# EPOCH : 717 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.008472828773168656
# EPOCH : 718 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.004560397748910233
# EPOCH : 719 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.011460472996261295
# EPOCH : 720 | 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다
# 0.004578189776624275
# EPOCH : 721 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.008493274388939112
# EPOCH : 722 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.004562829462043214
# EPOCH : 723 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0045212722012002715
# EPOCH : 724 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.00839077696455548
# EPOCH : 725 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.012586244008024897
# EPOCH : 726 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.004512159241107622
# EPOCH : 727 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.004471294627854117
# EPOCH : 728 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.004430958415134384
# EPOCH : 729 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.008318180544624867
# EPOCH : 730 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.008357538087891941
# EPOCH : 731 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.004446785968984478
# EPOCH : 732 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0044066160743747515
# EPOCH : 733 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.006629839283916833
# EPOCH : 734 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.00438581300992473
# EPOCH : 735 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.004346483089828539
# EPOCH : 736 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0043076577258992915
# EPOCH : 737 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0042693286652780785
# EPOCH : 738 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0042314878160271616
# EPOCH : 739 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.004194127243565972
# EPOCH : 740 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.00415723916719498
# EPOCH : 741 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.006467876549850239
# EPOCH : 742 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.004140995062252954
# EPOCH : 743 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.004104817622972136
# EPOCH : 744 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.007942784040028947
# EPOCH : 745 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.00409305017736513
# EPOCH : 746 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.004057436694265899
# EPOCH : 747 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.004022267386699287
# EPOCH : 748 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.007917970564848067
# EPOCH : 749 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 0.004014774840362792
# EPOCH : 750 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.003980070399704855
# ...
# 1.0733622663958338e-05
# EPOCH : 13877 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0727370536000192e-05
# EPOCH : 13878 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0721124332902475e-05
# EPOCH : 13879 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.
| 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.035432746733728e-05
# EPOCH : 14022 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0348432182829322e-05
# EPOCH : 14023 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0342542365573016e-05
# EPOCH : 14024 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0336658007238219e-05
# EPOCH : 14025 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0330779101114154e-05
# EPOCH : 14026 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0324905639432294e-05
# EPOCH : 14027 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.009437579018917
# EPOCH : 14028 | 목표 지점에 이르기까지 걸린 단계 수는 8단계입니다
# 1.036748530517436e-05
# EPOCH : 14029 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0361600729832596e-05
# EPOCH : 14030 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0355721591044382e-05
# EPOCH : 14031 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0349847880050667e-05
# EPOCH : 14032 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0343979591631667e-05
# EPOCH : 14033 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0338116717145858e-05
# EPOCH : 14034 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.033225925072944e-05
# EPOCH : 14035 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0326407185084433e-05
# EPOCH : 14036 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0320560512352105e-05
# EPOCH : 14037 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0314719226139565e-05
# EPOCH : 14038 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.030888331938866e-05
# EPOCH : 14039 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0303052785363455e-05
# EPOCH : 14040 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0297227616693112e-05
# EPOCH : 14041 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0291407806110875e-05
# EPOCH : 14042 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0285593347683121e-05
# EPOCH : 14043 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0279784232946568e-05
# EPOCH : 14044 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0273980456749522e-05
# EPOCH : 14045 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0268182010419232e-05
# EPOCH : 14046 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0262388887823451e-05
# EPOCH : 14047 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0256601082843375e-05
# EPOCH : 14048 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0250818586806255e-05
# EPOCH : 14049 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.024504139450792e-05
# EPOCH : 14050 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0239269497825092e-05
# EPOCH : 14051 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.023350289122791e-05
# EPOCH : 14052 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0227741566079182e-05
# EPOCH : 14053 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0221985517168668e-05
# EPOCH : 14054 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0216234736762104e-05
# EPOCH : 14055 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0210489218775813e-05
# EPOCH : 14056 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0204748955152006e-05
# EPOCH : 14057 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0199013940490487e-05
# EPOCH : 14058 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.019328416696115e-05
# EPOCH : 14059 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0187559628949128e-05
# EPOCH : 14060 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0181840318204509e-05
# EPOCH : 14061 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0176126228889516e-05
# EPOCH : 14062 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0170417354545339e-05
# EPOCH : 14063 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0164713687582129e-05
# EPOCH : 14064 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0159015221529368e-05
# EPOCH : 14065 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0153321950480323e-05
# EPOCH : 14066 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0147633867107087e-05
# EPOCH : 14067 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0141950964045326e-05
# EPOCH : 14068 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0136273235656756e-05
# EPOCH : 14069 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0130600675258353e-05
# EPOCH : 14070 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0124933275875228e-05
# EPOCH : 14071 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0119271030406291e-05
# EPOCH : 14072 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 0.0002656745055456401
# EPOCH : 14073 | 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 1.020942976146487e-05
# EPOCH : 14074 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0203724701812744e-05
# EPOCH : 14075 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.019802481561213e-05
# EPOCH : 14076 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.01923300952181e-05
# EPOCH : 14077 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0186640534098988e-05
# EPOCH : 14078 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.018095612674054e-05
# EPOCH : 14079 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0175276865396782e-05
# EPOCH : 14080 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0169602743668755e-05
# EPOCH : 14081 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0163933755282396e-05
# EPOCH : 14082 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0158269893503508e-05
# EPOCH : 14083 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0152611152064537e-05
# EPOCH : 14084 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0146957523593774e-05
# EPOCH : 14085 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0141309002936055e-05
# EPOCH : 14086 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0135665582605615e-05
# EPOCH : 14087 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.013002725559287e-05
# EPOCH : 14088 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0124394017083527e-05
# EPOCH : 14089 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0118765859164647e-05
# EPOCH : 14090 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0113142775840592e-05
# EPOCH : 14091 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.010752476054283e-05
# EPOCH : 14092 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0101911807036765e-05
# EPOCH : 14093 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0096303908786828e-05
# EPOCH : 14094 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.009070105891137e-05
# EPOCH : 14095 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0085103252073513e-05
# EPOCH : 14096 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0079510480649149e-05
# EPOCH : 14097 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0073922738764503e-05
# EPOCH : 14098 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.006834002022141e-05
# EPOCH : 14099 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.006276231851162e-05
# EPOCH : 14100 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0057189627115173e-05
# EPOCH : 14101 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0051621939746302e-05
# EPOCH : 14102 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.004605925034258e-05
# EPOCH : 14103 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.004050155184932e-05
# EPOCH : 14104 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0034948839002071e-05
# EPOCH : 14105 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0029401104191902e-05
# EPOCH : 14106 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0023858342162167e-05
# EPOCH : 14107 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0018320546544262e-05
# EPOCH : 14108 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0012787710196765e-05
# EPOCH : 14109 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.00072598279927e-05
# EPOCH : 14110 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 1.0001736892682658e-05
# EPOCH : 14111 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 9.996218898483504e-06
# EPOCH : 14112 | 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다

# %%
# 학습이 끝난 정책을 확인
np.set_printoptions(precision=3, suppress=True)  # 有効桁数3、指数表示しないという設定
print(pi)
# Out:
# [[0.    0.003 0.997 0.   ]
#  [0.    0.293 0.    0.707]
#  [0.    0.    0.408 0.592]
#  [0.002 0.995 0.003 0.   ]
#  [0.    0.    0.993 0.007]
#  [1.    0.    0.    0.   ]
#  [1.    0.    0.    0.   ]
#  [0.005 0.995 0.    0.   ]]

# %%
# 에이전트의 이동 과정을 시각화
# 참고 URL http://louistiao.me/posts/notebooks/embedding-matplotlib-animations-in-jupyter-notebooks/
from matplotlib import animation
from IPython.display import HTML


def init():
    # 배경 이미지 초기화
    line.set_data([], [])
    return (line,)


def animate(i):
    # 프레임 단위로 이미지 생성
    state = s_a_history[i][0]  # 현재 위치
    x = (state % 3) + 0.5  # 상태의 x좌표 : 3으로 나눈 나머지 + 0.5
    y = 2.5 - int(state / 3)  # y좌표 : 2.5에서 3으로 나눈 몫을 뺌
    line.set_data(x, y)
    return (line,)


#　초기화 함수와 프레임 단위 이미지 생성한수를 사용하여 애니메이션 생성
anim = animation.FuncAnimation(fig, animate, init_func=init, frames=len(
    s_a_history), interval=200, repeat=False)

HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img6730017774544a6891e7746aa0b2cce6">
#   <div class="anim-controls">
#     <input id="_anim_slider6730017774544a6891e7746aa0b2cce6" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim6730017774544a6891e7746aa0b2cce6.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim6730017774544a6891e7746aa0b2cce6.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim6730017774544a6891e7746aa0b2cce6.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim6730017774544a6891e7746aa0b2cce6.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim6730017774544a6891e7746aa0b2cce6.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim6730017774544a6891e7746aa0b2cce6.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim6730017774544a6891e7746aa0b2cce6.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim6730017774544a6891e7746aa0b2cce6.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim6730017774544a6891e7746aa0b2cce6.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim6730017774544a6891e7746aa0b2cce6.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select6730017774544a6891e7746aa0b2cce6"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_6730017774544a6891e7746aa0b2cce6"
#              checked>
#       <label for="_anim_radio1_6730017774544a6891e7746aa0b2cce6">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_6730017774544a6891e7746aa0b2cce6"
#              >
#       <label for="_anim_radio2_6730017774544a6891e7746aa0b2cce6">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_6730017774544a6891e7746aa0b2cce6"
#              >
#       <label for="_anim_radio3_6730017774544a6891e7746aa0b2cce6">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img6730017774544a6891e7746aa0b2cce6";
#     var slider_id = "_anim_slider6730017774544a6891e7746aa0b2cce6";
#     var loop_select_id = "_anim_loop_select6730017774544a6891e7746aa0b2cce6";
#     var frames = new Array(5);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjYuMCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy89olMNAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAsT0lEQV
